# %%
from random import randint
from time import sleep
from collections import deque
import threading


def put(num, event):
    global queue, is_sleeping
    while not event.wait(3):
        with locker:
            if not is_sleeping and len(queue) < 99:
                queue.append(randint(1, 100))
                print(f"Производитель {num} добавил: {queue[-1]}, длина текущей очереди: {len(queue)}")
                if len(queue) >= 99:
                    is_sleeping = True
            else:
                if len(queue) <= 80:
                    is_sleeping = False


def take(num, event):
    global queue
    sleep(3)
    while len(queue) > 0 and not event.wait(3):
        with locker:
            print(f"Потребитель {num} забрал: {queue[0]}")
            queue.popleft()
    if event:
        while len(queue) != 0:
            with locker:
                if len(queue) != 0:
                    print(f"Потребитель {num} забрал: {queue[0]}")
                    queue.popleft()
            sleep(2)


is_sleeping = False
locker = threading.Lock()
event = threading.Event()
queue = deque([], 200)
for i in range(3):
    t = threading.Thread(target = put, name = f'Производитель {i + 1}', args = (i+1, event)).start()
for i in range(2):
    t = threading.Thread(target = take, name = f'Потребитель {i + 1}', args = (i+1, event)).start()
letter = ''
print('Введите "q", чтобы завершить работу производителей', end = '\n\n')
while letter != 'q':
    letter = input()
event.set()
print("Очередь окончена\n")
# Out:
# Введите "q", чтобы завершить работу производителей
#
# Производитель 1 добавил: 95, длина текущей очереди: 1
# Производитель 3 добавил: 24, длина текущей очереди: 2
# Производитель 2 добавил: 78, длина текущей очереди: 3
# Потребитель 2 забрал: 95
# Производитель 2 добавил: 47, длина текущей очереди: 3
# Производитель 1 добавил: 46, длина текущей очереди: 4
# Производитель 3 добавил: 1, длина текущей очереди: 5
# Потребитель 1 забрал: 24
# Производитель 3 добавил: 7, длина текущей очереди: 5
# Производитель 1 добавил: 22, длина текущей очереди: 6
# Производитель 2 добавил: 24, длина текущей очереди: 7
# Потребитель 1 забрал: 78
# Потребитель 2 забрал: 47
# Производитель 3 добавил: 92, длина текущей очереди: 6
# Производитель 1 добавил: 82, длина текущей очереди: 7
# Потребитель 1 забрал: 46
# Производитель 2 добавил: 36, длина текущей очереди: 7
# Потребитель 2 забрал: 1
# Производитель 2 добавил: 69, длина текущей очереди: 7
# Производитель 1 добавил: 24, длина текущей очереди: 8
# Потребитель 2 забрал: 7
# Потребитель 1 забрал: 22
# Производитель 3 добавил: 75, длина текущей очереди: 7
# Производитель 2 добавил: 97, длина текущей очереди: 8
# Производитель 1 добавил: 75, длина текущей очереди: 9
# Потребитель 1 забрал: 24
# Производитель 3 добавил: 91, длина текущей очереди: 9
# Потребитель 2 забрал: 92
# Потребитель 2 забрал: 82
# Производитель 3 добавил: 73, длина текущей очереди: 8
# Производитель 1 добавил: 3, длина текущей очереди: 9
# Производитель 2 добавил: 8, длина текущей очереди: 10
# Потребитель 1 забрал: 36
# Потребитель 2 забрал: 69
# Производитель 3 добавил: 26, длина текущей очереди: 9
# Потребитель 1 забрал: 24
# Производитель 1 добавил: 63, длина текущей очереди: 9
# Производитель 2 добавил: 51, длина текущей очереди: 10
# Потребитель 2 забрал: 75
# Производитель 3 добавил: 38, длина текущей очереди: 10
# Потребитель 1 забрал: 97
# Производитель 2 добавил: 51, длина текущей очереди: 10
# Производитель 1 добавил: 89, длина текущей очереди: 11
# Производитель 3 добавил: 4, длина текущей очереди: 12
# Потребитель 2 забрал: 75
# Производитель 2 добавил: 29, длина текущей очереди: 12
# Производитель 1 добавил: 26, длина текущей очереди: 13
# Потребитель 1 забрал: 91
# Производитель 3 добавил: 15, длина текущей очереди: 13
# Потребитель 2 забрал: 73
# Производитель 2 добавил: 91, длина текущей очереди: 13
# Производитель 1 добавил: 20, длина текущей очереди: 14
# Потребитель 1 забрал: 3
# Производитель 3 добавил: 56, длина текущей очереди: 14
# Потребитель 2 забрал: 8
# Производитель 2 добавил: 23, длина текущей очереди: 14
# Производитель 1 добавил: 32, длина текущей очереди: 15
# Потребитель 1 забрал: 26
# Производитель 3 добавил: 23, длина текущей очереди: 15
# Потребитель 2 забрал: 63
# Производитель 2 добавил: 31, длина текущей очереди: 15
# Производитель 1 добавил: 94, длина текущей очереди: 16
# Потребитель 1 забрал: 51
# Производитель 3 добавил: 44, длина текущей очереди: 16
# Потребитель 2 забрал: 38
# Производитель 2 добавил: 71, длина текущей очереди: 16
# Производитель 1 добавил: 3, длина текущей очереди: 17
# Потребитель 1 забрал: 51
# Производитель 3 добавил: 60, длина текущей очереди: 17
# Потребитель 2 забрал: 89
# Производитель 2 добавил: 84, длина текущей очереди: 17
# Производитель 1 добавил: 36, длина текущей очереди: 18
# Потребитель 1 забрал: 4
# Потребитель 2 забрал: 29
# Производитель 3 добавил: 47, длина текущей очереди: 17
# Производитель 2 добавил: 92, длина текущей очереди: 18
# Производитель 1 добавил: 80, длина текущей очереди: 19
# Потребитель 1 забрал: 26
# Потребитель 2 забрал: 15
# Производитель 3 добавил: 65, длина текущей очереди: 18
# Производитель 1 добавил: 24, длина текущей очереди: 19
# Производитель 2 добавил: 80, длина текущей очереди: 20
# Потребитель 1 забрал: 91
# q
# Производитель 3 добавил: 16, длина текущей очереди: 20
# Потребитель 2 забрал: 20
# Производитель 2 добавил: 27, длина текущей очереди: 20
# Производитель 1 добавил: 55, длина текущей очереди: 21
# Потребитель 1 забрал: 56
# Очередь окончена
# Потребитель 2 забрал: 23
# Потребитель 1 забрал: 32
#
# Потребитель 2 забрал: 23
# Потребитель 1 забрал: 31
# Потребитель 2 забрал: 94
# Потребитель 1 забрал: 44
# Потребитель 2 забрал: 71
# Потребитель 1 забрал: 3
# Потребитель 2 забрал: 60
# Потребитель 1 забрал: 84
# Потребитель 2 забрал: 36
# Потребитель 1 забрал: 47
# Потребитель 2 забрал: 92
# Потребитель 1 забрал: 80
# Потребитель 2 забрал: 65
# Потребитель 1 забрал: 24
# Потребитель 2 забрал: 80
# Потребитель 1 забрал: 16
# Потребитель 1 забрал: 27
# Потребитель 2 забрал: 55
